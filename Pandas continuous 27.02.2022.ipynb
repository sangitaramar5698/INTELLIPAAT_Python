# %% [markdown]
# # Pandas continues
#     Selecting Columns

# %%
import numpy as np
import pandas as pd

# %%
market_df =pd.read_csv("E:\Downloads\market_fact.csv")

# %%
market_df
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
market_df[50:61]#if we want to take the middle row values
# Out:
#       Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 50  Ord_4682   Prod_5  SHP_6531  Cust_1579    63.9100      0.04
# 51  Ord_4768   Prod_4  SHP_6651  Cust_1579   547.0005      0.08
# 52  Ord_4755  Prod_13  SHP_6628  Cust_1579     3.4100      0.06
# 53  Ord_4659   Prod_6  SHP_6492  Cust_1579   391.9000      0.10
# 54  Ord_4682   Prod_4  SHP_6531  Cust_1579  1909.0065      0.01
# 55  Ord_4657   Prod_5  SHP_6489  Cust_1579   418.0300      0.00
# 56  Ord_4410   Prod_5  SHP_6146  Cust_1474   605.7700      0.05
# 57  Ord_4546   Prod_1  SHP_6327  Cust_1474  5208.7800      0.05
# 58  Ord_4499   Prod_6  SHP_6264  Cust_1474    67.4900      0.06
# 59  Ord_4552   Prod_4  SHP_6335  Cust_1474   284.4525      0.06
# 60  Ord_4552  Prod_12  SHP_6335  Cust_1474   104.7000      0.09
#
#     Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 50              14   -44.47           6.60                 0.49
# 51              10   -97.20           3.90                 0.55
# ...

# %%
market_df[50:250:5]#if i want to skip 5 rows in the middle part
# Out:
#        Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 50   Ord_4682   Prod_5  SHP_6531  Cust_1579     63.9100      0.04
# 55   Ord_4657   Prod_5  SHP_6489  Cust_1579    418.0300      0.00
# 60   Ord_4552  Prod_12  SHP_6335  Cust_1474    104.7000      0.09
# 65   Ord_4547   Prod_6  SHP_6328  Cust_1474     23.4400      0.05
# 70   Ord_4607   Prod_2  SHP_6408  Cust_1474   1463.4200      0.08
# 75   Ord_5216  Prod_13  SHP_7289  Cust_1749    141.5900      0.04
# 80   Ord_5174   Prod_6  SHP_7231  Cust_1749    292.7500      0.08
# 85   Ord_5232   Prod_6  SHP_7308  Cust_1758     88.5700      0.03
# 90    Ord_127  Prod_13   SHP_172    Cust_86     54.7800      0.02
# 95   Ord_5462   Prod_4  SHP_7632  Cust_1820    175.8565      0.03
# 100  Ord_1638   Prod_8  SHP_5892  Cust_1433    220.7900      0.00
# 105   Ord_122  Prod_17   SHP_165    Cust_45     42.3100      0.06
# 110   Ord_239   Prod_4   SHP_332    Cust_45   2157.3085      0.00
# ...

# %%
market_df[50:251:10]
# Out:
#        Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 50   Ord_4682   Prod_5  SHP_6531  Cust_1579    63.9100      0.04
# 60   Ord_4552  Prod_12  SHP_6335  Cust_1474   104.7000      0.09
# 70   Ord_4607   Prod_2  SHP_6408  Cust_1474  1463.4200      0.08
# 80   Ord_5174   Prod_6  SHP_7231  Cust_1749   292.7500      0.08
# 90    Ord_127  Prod_13   SHP_172    Cust_86    54.7800      0.02
# 100  Ord_1638   Prod_8  SHP_5892  Cust_1433   220.7900      0.00
# 110   Ord_239   Prod_4   SHP_332    Cust_45  2157.3085      0.00
# 120  Ord_5354   Prod_5  SHP_7480  Cust_1800   152.4400      0.08
# 130  Ord_2480   Prod_4  SHP_3397   Cust_933  1247.9275      0.10
# 140  Ord_1673   Prod_5  SHP_2313   Cust_498    23.9300      0.10
# 150  Ord_1635   Prod_1  SHP_2256   Cust_498   857.8400      0.02
# 160  Ord_1395   Prod_3  SHP_1926   Cust_515   158.9700      0.08
# 170  Ord_2973   Prod_4  SHP_4102  Cust_1480  6264.1855      0.01
# ...

# %%
market_df[10::5]#which will work till the end of gthe program
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  \
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641  4072.01      0.01
# 15    Ord_2280   Prod_5  SHP_3114   Cust_839   460.69      0.06
# 20     Ord_996  Prod_13  SHP_1378   Cust_371    57.17      0.08
# 25    Ord_2335  Prod_13  SHP_3204   Cust_931    38.26      0.03
# 30    Ord_2334   Prod_9  SHP_3203   Cust_931   129.10      0.00
# ...        ...      ...       ...        ...      ...       ...
# 8375  Ord_2772   Prod_3  SHP_3806  Cust_1006  1413.82      0.10
# 8380  Ord_2772   Prod_6  SHP_3807  Cust_1006   308.92      0.04
# 8385  Ord_1833   Prod_3  SHP_2527   Cust_637   611.16      0.04
# 8390  Ord_5435  Prod_16  SHP_7594  Cust_1798   316.99      0.04
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.16      0.10
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 10                43  1675.98           0.99                 0.56
# ...

# %%
market_df[:200:10]#which will take the start as the start value
# Out:
#        Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0    Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 10   Ord_4743   Prod_2  SHP_6615  Cust_1641  4072.0100      0.01
# 20    Ord_996  Prod_13  SHP_1378   Cust_371    57.1700      0.08
# 30   Ord_2334   Prod_9  SHP_3203   Cust_931   129.1000      0.00
# 40   Ord_5035  Prod_15  SHP_7024  Cust_1710  4917.6900      0.02
# 50   Ord_4682   Prod_5  SHP_6531  Cust_1579    63.9100      0.04
# 60   Ord_4552  Prod_12  SHP_6335  Cust_1474   104.7000      0.09
# 70   Ord_4607   Prod_2  SHP_6408  Cust_1474  1463.4200      0.08
# 80   Ord_5174   Prod_6  SHP_7231  Cust_1749   292.7500      0.08
# 90    Ord_127  Prod_13   SHP_172    Cust_86    54.7800      0.02
# 100  Ord_1638   Prod_8  SHP_5892  Cust_1433   220.7900      0.00
# 110   Ord_239   Prod_4   SHP_332    Cust_45  2157.3085      0.00
# 120  Ord_5354   Prod_5  SHP_7480  Cust_1800   152.4400      0.08
# ...

# %%
market_df[10:]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641  4072.0100      0.01
# 11    Ord_1925   Prod_6  SHP_2637   Cust_708   465.9000      0.05
# 12    Ord_2978  Prod_16  SHP_4112  Cust_1088   305.0500      0.04
# 13    Ord_2207  Prod_11  SHP_3093   Cust_839  3364.2480      0.10
# 14    Ord_2207  Prod_10  SHP_3006   Cust_839  1410.9300      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 10                43  1675.98           0.99                 0.56
# ...

# %%
market_df[:10]
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# 5  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.0200      0.03
# 6    Ord_31  Prod_12    SHP_41    Cust_26    14.7600      0.01
# 7  Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 8  Ord_4725  Prod_13  SHP_6593  Cust_1641   162.0000      0.01
# 9  Ord_4725   Prod_6  SHP_6593  Cust_1641    57.2200      0.07
#
#    Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0              23   -30.51           3.60                 0.56
# 1              13     4.56           0.93                 0.54
# 2              26  1148.90           2.50                 0.59
# ...

# %%
# Selecting Columns

# %%
market_df['Profit']
# Out:
# 0        -30.51
# 1          4.56
# 2       1148.90
# 3        729.34
# 4       1219.87
#          ...
# 8394     374.63
# 8395     -74.03
# 8396     -70.85
# 8397     565.34
# 8398     131.39
# Name: Profit, Length: 8399, dtype: float64

# %%
market_df.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin'],
#       dtype='object')

# %%
market_df.describe
# Out:
# <bound method NDFrame.describe of         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
market_df['Sales']
# Out:
# 0        136.8100
# 1         42.2700
# 2       4701.6900
# 3       2337.8900
# 4       4233.1500
#           ...
# 8394    2841.4395
# 8395     127.1600
# 8396     243.0500
# 8397    3872.8700
# 8398     603.6900
# Name: Sales, Length: 8399, dtype: float64

# %%
market_df.Profit
# Out:
# 0        -30.51
# 1          4.56
# 2       1148.90
# 3        729.34
# 4       1219.87
#          ...
# 8394     374.63
# 8395     -74.03
# 8396     -70.85
# 8397     565.34
# 8398     131.39
# Name: Profit, Length: 8399, dtype: float64

# %%
market_df.info
# Out:
# <bound method DataFrame.info of         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
print(type(market_df['Sales']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# #Selecting multiple columns
# you can select multiple col by passing the lsit of col names include
#inside the [[col1,col2,col3]]
market_df[['Profit','Sales','Shipping_Cost']]
# Out:
#        Profit      Sales  Shipping_Cost
# 0      -30.51   136.8100           3.60
# 1        4.56    42.2700           0.93
# 2     1148.90  4701.6900           2.50
# 3      729.34  2337.8900          14.30
# 4     1219.87  4233.1500          26.30
# ...       ...        ...            ...
# 8394   374.63  2841.4395           7.69
# 8395   -74.03   127.1600           6.92
# 8396   -70.85   243.0500           5.35
# 8397   565.34  3872.8700          30.00
# 8398   131.39   603.6900           4.86
#
# [8399 rows x 3 columns]

# %%
#similarly, if you select one  col using double sqr brackets
type(market_df[['Sales','Profit']])
# Out:
# pandas.core.frame.DataFrame

# %%
#to select a single row from the datasets
market_df[2:3]
# Out:
#      Ord_id Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 2  Ord_5446  Prod_4  SHP_7610  Cust_1818  4701.69       0.0              26
#
#    Profit  Shipping_Cost  Product_Base_Margin
# 2  1148.9            2.5                 0.59

# %%
market_df.index#to get an index of the table
# Out:
# RangeIndex(start=0, stop=8399, step=1)

# %%
#market_df[2]
#pandas throws an erroe because it is confused whether [2] is an index or a label
market_df.set_index('Order_Quantity').head()
# Out:
#                   Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  \
# Order_Quantity
# 23              Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01
# 13              Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01
# 26              Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00
# 43              Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09
# 35              Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08
#
#                  Profit  Shipping_Cost  Product_Base_Margin
# Order_Quantity
# 23               -30.51           3.60                 0.56
# 13                 4.56           0.93                 0.54
# 26              1148.90           2.50                 0.59
# 43               729.34          14.30                 0.37
# 35              1219.87          26.30                 0.38

# %%
# market_df.columns

# %%
market_df[13:15]
# Out:
#       Ord_id  Prod_id   Ship_id   Cust_id     Sales  Discount  Order_Quantity  \
# 13  Ord_2207  Prod_11  SHP_3093  Cust_839  3364.248      0.10              15
# 14  Ord_2207  Prod_10  SHP_3006  Cust_839  1410.930      0.08              10
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 13 -693.23          61.76                 0.78
# 14 -317.48          36.09                 0.77

# %%
#market_df[13]
#to select a single row in pandas is not possible, so we have to try something

# %% [markdown]
# # Position and label based indexing:
# # df.iloc and df.loc
#
# we have seen some ways of selecting some rows and coloums from df.
#
# there are 2 main ways of indexing df:
#
#
#     position based indexing using df.iloc
#
#     Label based indexing using df.loc

# %% [markdown]
# # Using both the methods, we will do the following indexing operations on a dataframe:
#     Selecting single data points
#     Selecting rows and coloumns

# %%
market_df.iloc[2]
# Out:
# Ord_id                  Ord_5446
# Prod_id                   Prod_4
# Ship_id                 SHP_7610
# Cust_id                Cust_1818
# Sales                    4701.69
# Discount                     0.0
# Order_Quantity                26
# Profit                    1148.9
# Shipping_Cost                2.5
# Product_Base_Margin         0.59
# Name: 2, dtype: object

# %%
#selcting a single row
market_df.loc[2]
# Out:
# Ord_id                  Ord_5446
# Prod_id                   Prod_4
# Ship_id                 SHP_7610
# Cust_id                Cust_1818
# Sales                    4701.69
# Discount                     0.0
# Order_Quantity                26
# Profit                    1148.9
# Shipping_Cost                2.5
# Product_Base_Margin         0.59
# Name: 2, dtype: object

# %%
#selcting multiple rows 
market_df.iloc[[4,3,5]]
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 5  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 4  1219.87          26.30                 0.38
# 3   729.34          14.30                 0.37
# 5   -47.64           6.15                 0.37

# %%
market_df.loc[[4,3,5]]
#selecting a multiple different rows i
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 5  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 4  1219.87          26.30                 0.38
# 3   729.34          14.30                 0.37
# 5   -47.64           6.15                 0.37

# %%
#selecting one particular value, like 3rd row 5th col
market_df.iloc[2,3]
# Out:
# 'Cust_1818'

# %% [markdown]
# # Selcting a particular value we need to use df.iloc
#     -Example: market_df.iloc[row,col]

# %%
market_df.iloc[2,4]
# Out:
# 4701.69

# %%
#selcting multiple rows and coloums values
market_df.iloc[[2,3,4],[2,4,5]]
# Out:
#     Ship_id    Sales  Discount
# 2  SHP_7610  4701.69      0.00
# 3  SHP_7625  2337.89      0.09
# 4  SHP_7664  4233.15      0.08

# %%
#giving range in iloc

market_df.iloc[4:10] #will give the range of 4 to 10 rows
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# 5  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.0200      0.03
# 6    Ord_31  Prod_12    SHP_41    Cust_26    14.7600      0.01
# 7  Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 8  Ord_4725  Prod_13  SHP_6593  Cust_1641   162.0000      0.01
# 9  Ord_4725   Prod_6  SHP_6593  Cust_1641    57.2200      0.07
#
#    Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 4              35  1219.87          26.30                 0.38
# 5              23   -47.64           6.15                 0.37
# 6               5     1.32           0.50                 0.36
# 7              48  1137.91           0.99                 0.55
# 8              33    45.84           0.71                 0.52
# 9               8   -27.72           6.60                 0.37

# %%
#to select a range of rows and coloumnstogether
market_df.iloc[4:10,0:4]
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818
# 5  Ord_5446   Prod_6  SHP_7608  Cust_1818
# 6    Ord_31  Prod_12    SHP_41    Cust_26
# 7  Ord_4725   Prod_4  SHP_6593  Cust_1641
# 8  Ord_4725  Prod_13  SHP_6593  Cust_1641
# 9  Ord_4725   Prod_6  SHP_6593  Cust_1641

# %%
market_df.iloc[2:3,2:4]
# Out:
#     Ship_id    Cust_id
# 2  SHP_7610  Cust_1818

# %%
#selct a multiple rows using a list of indices
market_df.iloc[[2,3,4,6]]
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
# 6    Ord_31  Prod_12    SHP_41    Cust_26    14.76      0.01               5
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 2  1148.90            2.5                 0.59
# 3   729.34           14.3                 0.37
# 4  1219.87           26.3                 0.38
# 6     1.32            0.5                 0.36

# %%
market_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ord_id               8399 non-null   object
#  1   Prod_id              8399 non-null   object
#  2   Ship_id              8399 non-null   object
#  3   Cust_id              8399 non-null   object
#  4   Sales                8399 non-null   float64
#  5   Discount             8399 non-null   float64
#  6   Order_Quantity       8399 non-null   int64
#  7   Profit               8399 non-null   float64
#  8   Shipping_Cost        8399 non-null   float64
#  9   Product_Base_Margin  8336 non-null   float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 656.3+ KB

# %% [markdown]
# # pandas.DataFrame.iloc
# property DataFrame.iloc
# Purely integer-location based indexing for selection by position.
#
# .iloc[] is primarily integer position based (from 0 to length-1 of the axis), but may also be used with a boolean array.
#
# Allowed inputs are:
#
# An integer, e.g. 5.
#
# A list or array of integers, e.g. [4, 3, 0].
#
# A slice object with ints, e.g. 1:7.
#
# A boolean array.
#
# A callable function with one argument (the calling Series or DataFrame) and that returns valid output for indexing (one of the above). This is useful in method chains, when you don’t have a reference to the calling object, but would like to base your selection on some value.

# %% [markdown]
# # Label based indexing
#
#     A single label '3' or 'row_index'
#     Alist of array of labels eg['3','4','5']
#     a range of labels row_x:row_y
#     A bool arrray
# # What is label

# %%
market_df.loc[2]
# Out:
# Ord_id                  Ord_5446
# Prod_id                   Prod_4
# Ship_id                 SHP_7610
# Cust_id                Cust_1818
# Sales                    4701.69
# Discount                     0.0
# Order_Quantity                26
# Profit                    1148.9
# Shipping_Cost                2.5
# Product_Base_Margin         0.59
# Name: 2, dtype: object

# %%
market_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
market_df.loc[2,'Sales']
# Out:
# 4701.69

# %%
market_df.set_index('Order_Quantity',inplace=True)

# %%
print(market_df.iloc[13])#when it is iloc, it will row values.
print(market_df.loc[13])#when loc, it will take the value 13 of order quantity is
# Out:
# Ord_id                 Ord_2207
# Prod_id                 Prod_11
# Ship_id                SHP_3093
# Cust_id                Cust_839
# Sales                  3364.248
# Discount                    0.1
# Profit                  -693.23
# Shipping_Cost             61.76
# Product_Base_Margin        0.78
# Name: 15, dtype: object
#                   Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# Order_Quantity
# 13              Ord_5406  Prod_13  SHP_7549  Cust_1818    42.270      0.01
# 13              Ord_2573   Prod_3  SHP_3525   Cust_931   197.610      0.08
# 13              Ord_2456   Prod_5  SHP_3367   Cust_931   109.580      0.00
# 13              Ord_5232   Prod_6  SHP_7309  Cust_1758    73.970      0.10
# 13              Ord_2372  Prod_10  SHP_3256   Cust_933  1764.970      0.07
# ...                  ...      ...       ...        ...       ...       ...
# 13              Ord_3218   Prod_6  SHP_4463  Cust_1190    98.390      0.01
# ...

# %%
market_df.loc[13]#when iloc, it will take the value 13 of order quantity is
# Out:
#                   Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# Order_Quantity
# 13              Ord_5406  Prod_13  SHP_7549  Cust_1818    42.270      0.01
# 13              Ord_2573   Prod_3  SHP_3525   Cust_931   197.610      0.08
# 13              Ord_2456   Prod_5  SHP_3367   Cust_931   109.580      0.00
# 13              Ord_5232   Prod_6  SHP_7309  Cust_1758    73.970      0.10
# 13              Ord_2372  Prod_10  SHP_3256   Cust_933  1764.970      0.07
# ...                  ...      ...       ...        ...       ...       ...
# 13              Ord_3218   Prod_6  SHP_4463  Cust_1190    98.390      0.01
# 13              Ord_1930  Prod_15  SHP_3133   Cust_889  1619.510      0.05
# 13               Ord_777   Prod_4  SHP_1065   Cust_245   603.347      0.08
# 13              Ord_4429   Prod_3  SHP_6173  Cust_1522   158.790      0.05
# 13              Ord_2153   Prod_4  SHP_2935   Cust_810  2175.218      0.07
#
# ...

# %%
market_df.loc[13]
# Out:
#                   Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# Order_Quantity
# 13              Ord_5406  Prod_13  SHP_7549  Cust_1818    42.270      0.01
# 13              Ord_2573   Prod_3  SHP_3525   Cust_931   197.610      0.08
# 13              Ord_2456   Prod_5  SHP_3367   Cust_931   109.580      0.00
# 13              Ord_5232   Prod_6  SHP_7309  Cust_1758    73.970      0.10
# 13              Ord_2372  Prod_10  SHP_3256   Cust_933  1764.970      0.07
# ...                  ...      ...       ...        ...       ...       ...
# 13              Ord_3218   Prod_6  SHP_4463  Cust_1190    98.390      0.01
# 13              Ord_1930  Prod_15  SHP_3133   Cust_889  1619.510      0.05
# 13               Ord_777   Prod_4  SHP_1065   Cust_245   603.347      0.08
# 13              Ord_4429   Prod_3  SHP_6173  Cust_1522   158.790      0.05
# 13              Ord_2153   Prod_4  SHP_2935   Cust_810  2175.218      0.07
#
# ...

# %% [markdown]
# # If i want to selct particular column value, which matches order_quantity 13

# %%
market_df.loc[13,'Sales']#here 13 is the value and the sales is the column value which is matching order_quantity 13
# Out:
# Order_Quantity
# 13      42.270
# 13     197.610
# 13     109.580
# 13      73.970
# 13    1764.970
#         ...
# 13      98.390
# 13    1619.510
# 13     603.347
# 13     158.790
# 13    2175.218
# Name: Sales, Length: 150, dtype: float64

# %%
#select multiple rows using a list of rows labels
market_df.loc[[3,7],'Sales']
# Out:
# Order_Quantity
# 3       73.44
# 3        6.76
# 3       23.44
# 3    21366.51
# 3       12.01
#        ...
# 7       44.64
# 7      140.77
# 7      887.94
# 7       88.59
# 7       56.90
# Name: Sales, Length: 363, dtype: float64

# %%
market_df.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Profit', 'Shipping_Cost', 'Product_Base_Margin'],
#       dtype='object')

# %%
# market_df.loc['Ord_5446',]

# %%
# Out:
#            Ship_id  Shipping_Cost   Profit
# Ord_id
# Ord_5446  SHP_7609           3.60   -30.51
# Ord_5446  SHP_7610           2.50  1148.90
# Ord_5446  SHP_7608           6.15   -47.64

# %%
market_df.set_index('Ord_id',inplace=True)

# %%
market_df.loc['Ord_5406', 'Ship_id':'Shipping_Cost']

# %%
market_df.loc['Ord_5446', ['Ship_id','Shipping_Cost','Profit']]
# Out:
#            Ship_id  Shipping_Cost   Profit
# Ord_id
# Ord_5446  SHP_7609           3.60   -30.51
# Ord_5446  SHP_7610           2.50  1148.90
# Ord_5446  SHP_7608           6.15   -47.64

# %%
market_df.head()
# Out:
#           Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#            Profit  Shipping_Cost  Product_Base_Margin
# Ord_id
# Ord_5446   -30.51           3.60                 0.56
# Ord_5406     4.56           0.93                 0.54
# Ord_5446  1148.90           2.50                 0.59
# Ord_5456   729.34          14.30                 0.37
# Ord_5485  1219.87          26.30                 0.38

# %%
market_df.loc['Ord_546','Ship_id':'Shipping_Cost']
# Out:
#          Ship_id   Cust_id     Sales  Discount  Order_Quantity  Profit  \
# Ord_id
# Ord_546  SHP_858  Cust_198  27875.54      0.00              46 -635.69
# Ord_546  SHP_858  Cust_198   2030.44      0.04              49  938.26
# Ord_546  SHP_741  Cust_198     48.84      0.01               2  -21.20
# Ord_546  SHP_859  Cust_198    695.99      0.09              47 -157.44
#
#          Shipping_Cost
# Ord_id
# Ord_546          24.49
# Ord_546           5.86
# Ord_546           9.03
# Ord_546           8.78

# %%
market_df.loc['Ord_5406', ['Ship_id','Shipping_Cost','Profit']]
# Out:
# Ship_id          SHP_7549
# Shipping_Cost        0.93
# Profit               4.56
# Name: Ord_5406, dtype: object

# %%
market_df.loc['Ord_5446','Ship_id':'Shipping_Cost']
# Out:
#            Ship_id    Cust_id    Sales  Discount  Order_Quantity   Profit  \
# Ord_id
# Ord_5446  SHP_7609  Cust_1818   136.81      0.01              23   -30.51
# Ord_5446  SHP_7610  Cust_1818  4701.69      0.00              26  1148.90
# Ord_5446  SHP_7608  Cust_1818   164.02      0.03              23   -47.64
#
#           Shipping_Cost
# Ord_id
# Ord_5446           3.60
# Ord_5446           2.50
# Ord_5446           6.15

# %%
customer_df=pd.read_csv("Data Science\cust_dimen.csv")

# %%
product_df=pd.read_csv("Data Science\prod_dimen.csv")

# %%
product_df
# Out:
#    Product_Category            Product_Sub_Category  Prod_id
# 0   OFFICE SUPPLIES          STORAGE & ORGANIZATION   Prod_1
# 1   OFFICE SUPPLIES                      APPLIANCES   Prod_2
# 2   OFFICE SUPPLIES  BINDERS AND BINDER ACCESSORIES   Prod_3
# 3        TECHNOLOGY    TELEPHONES AND COMMUNICATION   Prod_4
# 4         FURNITURE              OFFICE FURNISHINGS   Prod_5
# 5   OFFICE SUPPLIES                           PAPER   Prod_6
# 6   OFFICE SUPPLIES                    RUBBER BANDS   Prod_7
# 7        TECHNOLOGY            COMPUTER PERIPHERALS   Prod_8
# 8   OFFICE SUPPLIES                       ENVELOPES   Prod_9
# 9         FURNITURE                       BOOKCASES  Prod_10
# 10        FURNITURE                          TABLES  Prod_11
# 11  OFFICE SUPPLIES                          LABELS  Prod_12
# 12  OFFICE SUPPLIES             PENS & ART SUPPLIES  Prod_13
# 13       TECHNOLOGY                 COPIERS AND FAX  Prod_14
# ...

# %% [markdown]
# # Merging DataFrames using pd.merge()
#
# There are some ddata files
#     the market_fact table contains

# %%
market_df.head()
# Out:
#           Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#            Profit  Shipping_Cost  Product_Base_Margin
# Ord_id
# Ord_5446   -30.51           3.60                 0.56
# Ord_5406     4.56           0.93                 0.54
# Ord_5446  1148.90           2.50                 0.59
# Ord_5456   729.34          14.30                 0.37
# Ord_5485  1219.87          26.30                 0.38

# %%
customer_df.head()
# Out:
#         Customer_Name Province   Region Customer_Segment Cust_id
# 0  MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS  Cust_1
# 1        BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER  Cust_2
# 2       CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE  Cust_3
# 3      CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER  Cust_4
# 4        CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE  Cust_5

# %%
product_df.head()
# Out:
#   Product_Category            Product_Sub_Category Prod_id
# 0  OFFICE SUPPLIES          STORAGE & ORGANIZATION  Prod_1
# 1  OFFICE SUPPLIES                      APPLIANCES  Prod_2
# 2  OFFICE SUPPLIES  BINDERS AND BINDER ACCESSORIES  Prod_3
# 3       TECHNOLOGY    TELEPHONES AND COMMUNICATION  Prod_4
# 4        FURNITURE              OFFICE FURNISHINGS  Prod_5

# %%
## Merging the dataframes

# %%
new_df=pd.merge(market_df,customer_df)#for merging the market_df and customer_df

# %%
new_df
# Out:
#       Prod_id   Ship_id    Cust_id      Sales  Discount  Order_Quantity  \
# 0     Prod_16  SHP_7609  Cust_1818   136.8100      0.01              23
# 1     Prod_13  SHP_7549  Cust_1818    42.2700      0.01              13
# 2      Prod_4  SHP_7610  Cust_1818  4701.6900      0.00              26
# 3      Prod_6  SHP_7625  Cust_1818  2337.8900      0.09              43
# 4     Prod_17  SHP_7664  Cust_1818  4233.1500      0.08              35
# ...       ...       ...        ...        ...       ...             ...
# 8394   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08              28
# 8395   Prod_6  SHP_7555  Cust_1798   127.1600      0.10              20
# 8396   Prod_6  SHP_7524  Cust_1798   243.0500      0.02              39
# 8397  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03              23
# 8398   Prod_6  SHP_7628  Cust_1798   603.6900      0.00              47
#
#        Profit  Shipping_Cost  Product_Base_Margin   Customer_Name Province  \
# ...

# %%
market_df
# Out:
#           Prod_id   Ship_id    Cust_id      Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01              23
# Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01              13
# Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00              26
# Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09              43
# Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08              35
# ...           ...       ...        ...        ...       ...             ...
# Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08              28
# Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10              20
# Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02              39
# Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03              23
# Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00              47
#
# ...

# %%
new_df=pd.merge(market_df,customer_df,how='inner',on='Cust_id')

# %%
new_df
# Out:
#       Prod_id   Ship_id    Cust_id      Sales  Discount  Order_Quantity  \
# 0     Prod_16  SHP_7609  Cust_1818   136.8100      0.01              23
# 1     Prod_13  SHP_7549  Cust_1818    42.2700      0.01              13
# 2      Prod_4  SHP_7610  Cust_1818  4701.6900      0.00              26
# 3      Prod_6  SHP_7625  Cust_1818  2337.8900      0.09              43
# 4     Prod_17  SHP_7664  Cust_1818  4233.1500      0.08              35
# ...       ...       ...        ...        ...       ...             ...
# 8394   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08              28
# 8395   Prod_6  SHP_7555  Cust_1798   127.1600      0.10              20
# 8396   Prod_6  SHP_7524  Cust_1798   243.0500      0.02              39
# 8397  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03              23
# 8398   Prod_6  SHP_7628  Cust_1798   603.6900      0.00              47
#
#        Profit  Shipping_Cost  Product_Base_Margin   Customer_Name Province  \
# ...

# %%
new_df.head()
# Out:
#    Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity   Profit  \
# 0  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23   -30.51
# 1  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13     4.56
# 2   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26  1148.90
# 3   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43   729.34
# 4  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35  1219.87
#
#    Shipping_Cost  Product_Base_Margin  Customer_Name Province Region  \
# 0           3.60                 0.56  AARON BERGMAN  ALBERTA   WEST
# 1           0.93                 0.54  AARON BERGMAN  ALBERTA   WEST
# 2           2.50                 0.59  AARON BERGMAN  ALBERTA   WEST
# 3          14.30                 0.37  AARON BERGMAN  ALBERTA   WEST
# 4          26.30                 0.38  AARON BERGMAN  ALBERTA   WEST
#
#   Customer_Segment
# 0        CORPORATE
# 1        CORPORATE
# 2        CORPORATE
# ...

# %%
# dummy_df=pd.merge(market_df,customer_df,how='inner',left_on='cust_num')
# #when it is having the same values with different colo=umn name

# %%
master_df=pd.merge(new_df,product_df,how='inner',on='Prod_id')
master_df.head()
# Out:
#    Prod_id   Ship_id    Cust_id   Sales  Discount  Order_Quantity  Profit  \
# 0  Prod_16  SHP_7609  Cust_1818  136.81      0.01              23  -30.51
# 1  Prod_16  SHP_4112  Cust_1088  305.05      0.04              27   23.12
# 2  Prod_16  SHP_7663  Cust_1820  322.82      0.05              35  -17.58
# 3  Prod_16  SHP_5175  Cust_1314  459.08      0.04              34   61.57
# 4  Prod_16  SHP_5771  Cust_1417  207.21      0.06              24  -78.64
#
#    Shipping_Cost  Product_Base_Margin        Customer_Name       Province  \
# 0           3.60                 0.56        AARON BERGMAN        ALBERTA
# 1           3.37                 0.57        AARON HAWKINS        ONTARIO
# 2           3.98                 0.56         ADRIAN SHAMI        ALBERTA
# 3           3.14                 0.60  ALEKSANDRA GANNAWAY    SASKACHEWAN
# 4           6.14                 0.59         ALLEN ARMOLD  NEW BRUNSWICK
#
# ...

# %%
#Inner, left, right and outer JOINS IN SQL

# %%
master_df.to_csv("Data Science\Master_data.csv",index=False)

# %%
# we can perform let, right and outer merges (joints ) by using the argumernt how='left'/'right'/'outer'

# %% [markdown]
# # Concatenating DataFrames

# %%
pd.concat([market_df,product_df],axis=0)
# Out:
#           Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01            23.0
# Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01            13.0
# Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00            26.0
# Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09            43.0
# Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08            35.0
# ...           ...       ...        ...      ...       ...             ...
# 12        Prod_13       NaN        NaN      NaN       NaN             NaN
# 13        Prod_14       NaN        NaN      NaN       NaN             NaN
# 14        Prod_15       NaN        NaN      NaN       NaN             NaN
# 15        Prod_16       NaN        NaN      NaN       NaN             NaN
# 16        Prod_17       NaN        NaN      NaN       NaN             NaN
#
#            Profit  Shipping_Cost  Product_Base_Margin Product_Category  \
# ...

# %%
df1=pd.DataFrame({'Name':['Akhil','Asha','Preeti'],'Age':[34,23,45],'Gender':['M','F','M']})
df1
# Out:
#      Name  Age Gender
# 0   Akhil   34      M
# 1    Asha   23      F
# 2  Preeti   45      M

# %%
df2=pd.DataFrame({'Name':['Aman','Aer','Prei'],'ID_NUMBER':[23,65,5],'Gr':['F','M','M']})
df2
# Out:
#    Name  ID_NUMBER Gr
# 0  Aman         23  F
# 1   Aer         65  M
# 2  Prei          5  M

# %%
pd.concat([df1,df2],axis = 0)#if we wants to concat in row wise axis=0
#do row wise concat, only columns are same, or else u wille nd up with result like below
# Out:
#      Name   Age Gender  ID_NUMBER   Gr
# 0   Akhil  34.0      M        NaN  NaN
# 1    Asha  23.0      F        NaN  NaN
# 2  Preeti  45.0      M        NaN  NaN
# 0    Aman   NaN    NaN       23.0    F
# 1     Aer   NaN    NaN       65.0    M
# 2    Prei   NaN    NaN        5.0    M

# %%
pd.concat([df1,df2],axis = 1)#when we wants to concat in column wise
# Out:
#      Name  Age Gender  Name  ID_NUMBER Gr
# 0   Akhil   34      M  Aman         23  F
# 1    Asha   23      F   Aer         65  M
# 2  Preeti   45      M  Prei          5  M

# %% [markdown]
# # Cleaning of the dataSet
#
# clearing the issues in the datasets

# %%
housing=pd.read_csv("Data Science\melbourne.csv")
housing.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03-09-2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  03-12-2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  04-02-2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  04-02-2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  04-03-2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
#isnull()
#if it is true then the data is missing on that location
housing.isnull().sum()
#will provide the no of missing values present in each column
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             5151
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          4481
# Bathroom          4484
# Car               4626
# Landsize          6137
# BuildingArea     13529
# YearBuilt        12007
# CouncilArea       7891
# Lattitude         4304
# Longtitude        4304
# Regionname           1
# Propertycount        1
# dtype: int64

# %%
housing
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 0        Abbotsford       68 Studley St      2    h        NaN     SS
# 1        Abbotsford        85 Turner St      2    h  1480000.0      S
# 2        Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3        Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4        Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...             ...                 ...    ...  ...        ...    ...
# 23542  Wyndham Vale     25 Clitheroe Dr      3    u        NaN     PN
# 23543  Wyndham Vale    19 Dalrymple Bvd      4    h        NaN      S
# 23544     Yallambie        17 Amaroo Wy      4    h  1100000.0      S
# 23545    Yarraville          6 Agnes St      4    h  1285000.0     SP
# 23546    Yarraville       33 Freeman St      4    h  1050000.0     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %%
housing= housing.drop('BuildingArea',axis=1)
#axis 1 is column
#building areA column is dropped, which means deleted as it is unwanted

# %%
housing
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 0        Abbotsford       68 Studley St      2    h        NaN     SS
# 1        Abbotsford        85 Turner St      2    h  1480000.0      S
# 2        Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3        Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4        Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...             ...                 ...    ...  ...        ...    ...
# 23542  Wyndham Vale     25 Clitheroe Dr      3    u        NaN     PN
# 23543  Wyndham Vale    19 Dalrymple Bvd      4    h        NaN      S
# 23544     Yallambie        17 Amaroo Wy      4    h  1100000.0      S
# 23545    Yarraville          6 Agnes St      4    h  1285000.0     SP
# 23546    Yarraville       33 Freeman St      4    h  1050000.0     VB
#
#              SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# ...

# %%
housing=housing.drop(columns=["YearBuilt","CouncilArea"])

# %%
housing.isnull().sum()#row wise missing value count
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price            5151
# Method              0
# SellerG             0
# Date                0
# Distance            1
# Postcode            1
# Bedroom2         4481
# Bathroom         4484
# Car              4626
# Landsize         6137
# Lattitude        4304
# Longtitude       4304
# Regionname          1
# Propertycount       1
# dtype: int64

# %%
housing.isnull().sum(axis=0)#col wise missing value count
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price            5151
# Method              0
# SellerG             0
# Date                0
# Distance            1
# Postcode            1
# Bedroom2         4481
# Bathroom         4484
# Car              4626
# Landsize         6137
# Lattitude        4304
# Longtitude       4304
# Regionname          1
# Propertycount       1
# dtype: int64

# %%
#there are missing values in Price, but i cant drop it,
#so we can fix it
housing['Price']=housing.Price.fillna(housing.Price.mean())
#fillna provides a feature to fill the NAN position with the value we give

# %%
housing.Price.mean()
# Out:
# 1056697.4609153082

# %%
housing.Price
# Out:
# 0        1.056697e+06
# 1        1.480000e+06
# 2        1.035000e+06
# 3        1.056697e+06
# 4        1.465000e+06
#              ...
# 23542    1.056697e+06
# 23543    1.056697e+06
# 23544    1.100000e+06
# 23545    1.285000e+06
# 23546    1.050000e+06
# Name: Price, Length: 23547, dtype: float64

# %%
housing.drop_duplicates()
# Out:
#              Suburb             Address  Rooms Type         Price Method  \
# 0        Abbotsford       68 Studley St      2    h  1.056697e+06     SS
# 1        Abbotsford        85 Turner St      2    h  1.480000e+06      S
# 2        Abbotsford     25 Bloomburg St      2    h  1.035000e+06      S
# 3        Abbotsford  18/659 Victoria St      3    u  1.056697e+06     VB
# 4        Abbotsford        5 Charles St      3    h  1.465000e+06     SP
# ...             ...                 ...    ...  ...           ...    ...
# 23542  Wyndham Vale     25 Clitheroe Dr      3    u  1.056697e+06     PN
# 23543  Wyndham Vale    19 Dalrymple Bvd      4    h  1.056697e+06      S
# 23544     Yallambie        17 Amaroo Wy      4    h  1.100000e+06      S
# 23545    Yarraville          6 Agnes St      4    h  1.285000e+06     SP
# 23546    Yarraville       33 Freeman St      4    h  1.050000e+06     VB
#
#              SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# ...

# %% [markdown]
# # Renaming operation
#
# # Df.rename(columns={"Old_col_name" : "New Col name"})

# %%
housing.rename(columns={"Bedroom2":"Bedroom"})
# Out:
#              Suburb             Address  Rooms Type         Price Method  \
# 0        Abbotsford       68 Studley St      2    h  1.056697e+06     SS
# 1        Abbotsford        85 Turner St      2    h  1.480000e+06      S
# 2        Abbotsford     25 Bloomburg St      2    h  1.035000e+06      S
# 3        Abbotsford  18/659 Victoria St      3    u  1.056697e+06     VB
# 4        Abbotsford        5 Charles St      3    h  1.465000e+06     SP
# ...             ...                 ...    ...  ...           ...    ...
# 23542  Wyndham Vale     25 Clitheroe Dr      3    u  1.056697e+06     PN
# 23543  Wyndham Vale    19 Dalrymple Bvd      4    h  1.056697e+06      S
# 23544     Yallambie        17 Amaroo Wy      4    h  1.100000e+06      S
# 23545    Yarraville          6 Agnes St      4    h  1.285000e+06     SP
# 23546    Yarraville       33 Freeman St      4    h  1.050000e+06     VB
#
#              SellerG        Date  Distance  Postcode  Bedroom  Bathroom  Car  \
# ...

# %% [markdown]
# # Applying filters on the Data

# %%
market= pd.read_csv("Data Science/market_fact.csv")

# %%
market
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
market['Profit']>1000#this will print only where the profit is greater than 1000 column
#market.Profit>1000 also works
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 8394    False
# 8395    False
# 8396    False
# 8397    False
# 8398    False
# Name: Profit, Length: 8399, dtype: bool

# %%
market[market['Profit']>1000]# but here it will filter all the rows, where the profit>1000
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818   4701.6900      0.00
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818   4233.1500      0.08
# 7     Ord_4725   Prod_4  SHP_6593  Cust_1641   3410.1575      0.10
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.0100      0.01
# 17    Ord_4471  Prod_15  SHP_6228  Cust_1521  13255.9300      0.02
# ...        ...      ...       ...        ...         ...       ...
# 8317  Ord_2770   Prod_3  SHP_3802  Cust_1016   7535.9600      0.08
# 8343  Ord_2178   Prod_4  SHP_2968   Cust_785   6030.5800      0.09
# 8366  Ord_3593   Prod_3  SHP_4974  Cust_1274  12073.0600      0.03
# 8367  Ord_3593  Prod_15  SHP_4975  Cust_1274   6685.0500      0.09
# 8371  Ord_2624   Prod_4  SHP_3591  Cust_1006   4924.1350      0.07
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 2                 26  1148.90           2.50                 0.59
# ...

# %%
Highest_Sales=market[market.Sales>4000]

# %%
Highest_Sales.to_csv("Data Science\highest_Sale.csv")

# %%
market[(market.Sales>2000) | (market.Profit > 1000)]
#to get the rows,in which sales>2000 or profit>1000>
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# 7     Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641  4072.0100      0.01
# ...        ...      ...       ...        ...        ...       ...
# 8371  Ord_2624   Prod_4  SHP_3591  Cust_1006  4924.1350      0.07
# 8381  Ord_2696   Prod_4  SHP_3691  Cust_1006  2836.0505      0.01
# 8383  Ord_2722   Prod_1  SHP_3731  Cust_1006  3508.3300      0.04
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 2                 26  1148.90           2.50                 0.59
# ...

# %%
market[(market.Sales>2000) & (market.Profit > 1000)]
#to get the rows,in which sales>2000 and profit>1000>
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818   4701.6900      0.00
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818   4233.1500      0.08
# 7     Ord_4725   Prod_4  SHP_6593  Cust_1641   3410.1575      0.10
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.0100      0.01
# 17    Ord_4471  Prod_15  SHP_6228  Cust_1521  13255.9300      0.02
# ...        ...      ...       ...        ...         ...       ...
# 8317  Ord_2770   Prod_3  SHP_3802  Cust_1016   7535.9600      0.08
# 8343  Ord_2178   Prod_4  SHP_2968   Cust_785   6030.5800      0.09
# 8366  Ord_3593   Prod_3  SHP_4974  Cust_1274  12073.0600      0.03
# 8367  Ord_3593  Prod_15  SHP_4975  Cust_1274   6685.0500      0.09
# 8371  Ord_2624   Prod_4  SHP_3591  Cust_1006   4924.1350      0.07
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 2                 26  1148.90           2.50                 0.59
# ...

# %%
market.loc[(market.Sales>3000) & (market.Profit > 1000),['Sales','Profit','Discount']]
# Out:
#            Sales   Profit  Discount
# 2      4701.6900  1148.90      0.00
# 4      4233.1500  1219.87      0.08
# 7      3410.1575  1137.91      0.10
# 10     4072.0100  1675.98      0.01
# 17    13255.9300  4089.27      0.02
# ...          ...      ...       ...
# 8317   7535.9600  2745.87      0.08
# 8343   6030.5800  1197.86      0.09
# 8366  12073.0600  5081.87      0.03
# 8367   6685.0500  1653.60      0.09
# 8371   4924.1350  1049.54      0.07
#
# [643 rows x 3 columns]

# %%
#when we need to check like, cust_is not  is Cust_1818
market[market.Cust_id !='Cust_1818']
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 6       Ord_31  Prod_12    SHP_41    Cust_26    14.7600      0.01
# 7     Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 8     Ord_4725  Prod_13  SHP_6593  Cust_1641   162.0000      0.01
# 9     Ord_4725   Prod_6  SHP_6593  Cust_1641    57.2200      0.07
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641  4072.0100      0.01
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 6                  5     1.32           0.50                 0.36
# ...

# %%
#when we need to check like, cust_  is Cust_1818
market[market.Cust_id =='Cust_1818']
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
# 5  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38
# 5   -47.64           6.15                 0.37

# %% [markdown]
# # Sort the values based on some point using sort_values

# %%
#highest sales will be shown in top
market[market.Sales>2500].sort_values('Sales',ascending=False,ignore_index=True).head(20)
# Out:
#       Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 0   Ord_3084  Prod_17  SHP_4279  Cust_1151  89061.05      0.00
# 1   Ord_2338  Prod_17  SHP_3207   Cust_932  45923.76      0.07
# 2   Ord_3875  Prod_17  SHP_5370  Cust_1351  41343.21      0.09
# 3   Ord_2373  Prod_14  SHP_3259   Cust_942  33367.85      0.01
# 4   Ord_4614  Prod_14  SHP_6423  Cust_1571  29884.60      0.05
# 5   Ord_3170  Prod_10  SHP_4400  Cust_1162  29345.27      0.03
# 6   Ord_3727  Prod_17  SHP_5171  Cust_1310  29186.49      0.05
# 7    Ord_997  Prod_14  SHP_1379   Cust_365  28761.52      0.04
# 8   Ord_3143  Prod_14  SHP_4362  Cust_1170  28664.52      0.09
# 9   Ord_3359  Prod_10  SHP_7245  Cust_1762  28389.14      0.07
# 10  Ord_3707  Prod_17  SHP_5136  Cust_1307  28359.40      0.05
# 11   Ord_911  Prod_10  SHP_1255   Cust_302  28180.08      0.02
# 12   Ord_546  Prod_14   SHP_858   Cust_198  27875.54      0.00
# 13  Ord_2425  Prod_14  SHP_3329   Cust_934  27820.34      0.08
# ...

# %%
#highest sales will be shown in top
top20_highest_sales=market[market.Sales>2500].sort_values('Sales',ascending=False,ignore_index=True).head(20)
top20_highest_sales
# Out:
#       Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 0   Ord_3084  Prod_17  SHP_4279  Cust_1151  89061.05      0.00
# 1   Ord_2338  Prod_17  SHP_3207   Cust_932  45923.76      0.07
# 2   Ord_3875  Prod_17  SHP_5370  Cust_1351  41343.21      0.09
# 3   Ord_2373  Prod_14  SHP_3259   Cust_942  33367.85      0.01
# 4   Ord_4614  Prod_14  SHP_6423  Cust_1571  29884.60      0.05
# 5   Ord_3170  Prod_10  SHP_4400  Cust_1162  29345.27      0.03
# 6   Ord_3727  Prod_17  SHP_5171  Cust_1310  29186.49      0.05
# 7    Ord_997  Prod_14  SHP_1379   Cust_365  28761.52      0.04
# 8   Ord_3143  Prod_14  SHP_4362  Cust_1170  28664.52      0.09
# 9   Ord_3359  Prod_10  SHP_7245  Cust_1762  28389.14      0.07
# 10  Ord_3707  Prod_17  SHP_5136  Cust_1307  28359.40      0.05
# 11   Ord_911  Prod_10  SHP_1255   Cust_302  28180.08      0.02
# 12   Ord_546  Prod_14   SHP_858   Cust_198  27875.54      0.00
# 13  Ord_2425  Prod_14  SHP_3329   Cust_934  27820.34      0.08
# ...

# %%
top20_highest_sales.to_csv("Data Science\Top20_highest.csv")
